# %%
from sqlalchemy import create_engine
import pandas as pd
#%load_ext sql
engine = create_engine('postgresql://postgres:A1A3AA989@localhost:5437/employees')

# %%
query = '''select e.emp_no,e.last_name,e.first_name,e.sex,e.emp_title_id,ti.title_id,s.salary 
from Employees as e 
inner join salaries as s on e.emp_no = s.emp_no
inner join titles as ti on ti.title_id = e.emp_title_id'''
salary_df = pd.read_sql(query,engine)
salary_df




#query = '''select e.emp_no,e.last_name,e.first_name,e.sex,s.salary 
#from Employees as e inner join salaries as s on e.emp_no = s.emp_no'''
#salary_df = pd.read_sql(query,engine)
#salary_df




#%%sql

#select e.emp_no,e.last_name,e.first_name,e.sex,s.salary from Employees as e
#inner join salaries as s on e.emp_no = s.emp_no

#LIMIT 3
# Out:
#         emp_no    last_name first_name sex emp_title_id title_id  salary
# 0        10005     Maliniak    Kyoichi   M        s0001    s0001   78228
# 1        10010     Piveteau  Duangkaew   F        e0002    e0002   72488
# 2        10011        Sluis       Mary   F        s0001    s0001   42365
# 3        10013       Terkki  Eberhardt   M        s0002    s0002   40000
# 4        10017    Bouloucos  Cristinel   F        s0001    s0001   71380
# ...        ...          ...        ...  ..          ...      ...     ...
# 300019  499948    Paludetto   Cordelia   M        e0002    e0002   40000
# 300020  499972       Leuchs     Katsuo   F        e0003    e0003   41002
# 300021  499985  Lukaszewicz       Gila   M        s0001    s0001   40000
# 300022  499987       Dusink      Rimli   F        s0001    s0001   52282
# 300023  499998      Breugel   Patricia   M        s0001    s0001   40000
#
# [300024 rows x 7 columns]

# %%
#Create a histogram to visualize the most common salary ranges for employees.
salary_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Create a bar chart of average salary by title.
salary_title= salary_df[['salary','title_id']]
salary_title
# Out:
#         salary title_id
# 0        78228    s0001
# 1        72488    e0002
# 2        42365    s0001
# 3        40000    s0002
# 4        71380    s0001
# ...        ...      ...
# 300019   40000    e0002
# 300020   41002    e0003
# 300021   40000    s0001
# 300022   52282    s0001
# 300023   40000    s0001
#
# [300024 rows x 2 columns]

# %%
salary_title.plot.bar()
